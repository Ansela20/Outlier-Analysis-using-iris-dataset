# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from pylab import rcParams

# %%
# %matplotlib inline
rcParams['figure.figsize']= 5,4

# %%
address = 'C:/Users/Ansela/Desktop/DataSet/Python/iris.csv'
iris_df = pd.read_csv(filepath_or_buffer = address, header = None,sep=',')
iris_df.columns = ['Index','Sepal Length', 'Sepal Width', 'Petal Length','Petal Width','Species']
iris_df.head()
# Out:
#    Index  Sepal Length  Sepal Width  Petal Length  Petal Width  Species
# 0    NaN  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  Species
# 1    1.0           5.1          3.5           1.4          0.2   setosa
# 2    2.0           4.9            3           1.4          0.2   setosa
# 3    3.0           4.7          3.2           1.3          0.2   setosa
# 4    4.0           4.6          3.1           1.5          0.2   setosa

# %%
iris =iris_df.drop(['Index'], axis=1)
iris =iris.drop([0])
iris_d = pd.DataFrame(iris, columns=['Sepal Length','Sepal Width', 'Petal Length','Petal Width'], dtype='float')
iris_d[:5]
# Out:
#    Sepal Length  Sepal Width  Petal Length  Petal Width
# 1           5.1          3.5           1.4          0.2
# 2           4.9          3.0           1.4          0.2
# 3           4.7          3.2           1.3          0.2
# 4           4.6          3.1           1.5          0.2
# 5           5.0          3.6           1.4          0.2

# %%
x = iris.iloc[:,0:4].values
y = iris.iloc[:,4].values

# %%
#Identifying outliers from Tukey boxplots
iris_d.boxplot(return_type='dict')
plt.plot()
# Out:
# []

# %%
Sepal_Width = x[:,1]
iris_outliers = (Sepal_Width > '4') # Record that have sample width > 4
iris[iris_outliers]
# Out:
#    Sepal Length Sepal Width Petal Length Petal Width Species
# 16          5.7         4.4          1.5         0.4  setosa
# 33          5.2         4.1          1.5         0.1  setosa
# 34          5.5         4.2          1.4         0.2  setosa

# %%
Sepal_Width = x[:,1]
iris_outliers = (Sepal_Width < '2.05') # Record that have sample width <2.05
iris[iris_outliers]
# Out:
#    Sepal Length Sepal Width Petal Length Petal Width     Species
# 61            5           2          3.5           1  versicolor

# %%
# Multivariate analysis for outlier detction
import seaborn as sb
sb.set_style('whitegrid')

# %%
iris.head()
# Out:
#   Sepal Length Sepal Width Petal Length Petal Width Species
# 1          5.1         3.5          1.4         0.2  setosa
# 2          4.9           3          1.4         0.2  setosa
# 3          4.7         3.2          1.3         0.2  setosa
# 4          4.6         3.1          1.5         0.2  setosa
# 5            5         3.6          1.4         0.2  setosa

# %%
data = iris.iloc[:,0:4].values
target = iris.iloc[:,4].values

# %%
# To change the datatype to float
u= pd.DataFrame(data, dtype ='float')
u.columns = ['Sepal Length', 'Sepal Width', 'Petal Length','Petal Width']
u.head()
# Out:
#    Sepal Length  Sepal Width  Petal Length  Petal Width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
v= pd.DataFrame(target)
v.columns = ['Species']
v.head()
# Out:
#   Species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
u = pd.concat([u,v], axis=1)
u.head()
# Out:
#    Sepal Length  Sepal Width  Petal Length  Petal Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sb.boxplot(x='Species', y='Sepal Length', data=u , palette='hls')
# Out:
# <AxesSubplot:xlabel='Species', ylabel='Sepal Length'>

# %%
sb.pairplot(u, hue= 'Species')
plt.show()
